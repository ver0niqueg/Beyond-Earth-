# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/exoplanets_raw.csv', comment='#')

print(f"Rows: {df.shape[0]}")
print(f"Columns: {df.shape[1]}")
df.head()
# Out:
# Rows: 39443
# Columns: 100
# /tmp/ipykernel_206726/641057413.py:1: DtypeWarning: Columns (12,13,37,38,52,53,54,55,70,71,78,79,81,94,95,96,97) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../data/exoplanets_raw.csv', comment='#')
#     pl_name hostname  default_flag  sy_snum  sy_pnum  discoverymethod  \
# 0  11 Com b   11 Com             1        2        1  Radial Velocity
# 1  11 Com b   11 Com             0        2        1  Radial Velocity
# 2  11 Com b   11 Com             0        2        1  Radial Velocity
# 3  11 UMi b   11 UMi             0        1        1  Radial Velocity
# 4  11 UMi b   11 UMi             1        1        1  Radial Velocity
#
#    disc_year                           disc_facility              soltype  \
# 0     2007.0                        Xinglong Station  Published Confirmed
# 1     2007.0                        Xinglong Station  Published Confirmed
# 2     2007.0                        Xinglong Station  Published Confirmed
# 3     2009.0  Thueringer Landessternwarte Tautenburg  Published Confirmed
# 4     2009.0  Thueringer Landessternwarte Tautenburg  Published Confirmed
#
#    pl_controv_flag  ... pl_pubdate releasedate Unnamed: 92 Unnamed: 93  \
# 0                0  ...    2023-08  2023-09-19         NaN         NaN
# 1                0  ...    2008-01  2014-05-14         NaN         NaN
# 2                0  ...    2011-08  2014-07-23         NaN         NaN
# 3                0  ...    2009-10  2014-05-14         NaN         NaN
# 4                0  ...    2017-03  2018-09-06         NaN         NaN
#
#    Unnamed: 94  Unnamed: 95  Unnamed: 96  Unnamed: 97  Unnamed: 98  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 99
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 100 columns]

# %%
useful_columns = [
    'pl_name', 'disc_year', 'discoverymethod',
    'pl_rade', 'pl_bmasse', 'pl_orbper',
    'sy_dist', 'pl_eqt', 'st_teff', 'sy_snum'
]

df = df[useful_columns]
print(df.shape)
df.head()
# Out:
# (39443, 10)
#     pl_name  disc_year  discoverymethod  pl_rade    pl_bmasse  pl_orbper  \
# 0  11 Com b     2007.0  Radial Velocity      NaN  4914.898486     323.21
# 1  11 Com b     2007.0  Radial Velocity      NaN  6165.600000     326.03
# 2  11 Com b     2007.0  Radial Velocity      NaN  5434.700000        NaN
# 3  11 UMi b     2009.0  Radial Velocity      NaN  3337.070000     516.22
# 4  11 UMi b     2009.0  Radial Velocity      NaN  4684.814200  516.21997
#
#    sy_dist  pl_eqt st_teff  sy_snum
# 0  93.1846     NaN    4874        2
# 1  93.1846     NaN    4742        2
# 2  93.1846     NaN     NaN        2
# 3  125.321     NaN    4340        1
# 4  125.321     NaN    4213        1

# %%
df = df.drop_duplicates(subset='pl_name', keep='first')

print(f"Unique planets: {df.shape[0]}")
# Out:
# Unique planets: 6128

# %%
df.isnull().sum()
# Out:
# pl_name               0
# disc_year             1
# discoverymethod       0
# pl_rade            2400
# pl_bmasse          3770
# pl_orbper           563
# sy_dist             128
# pl_eqt             3415
# st_teff            1047
# sy_snum               0
# dtype: int64

# %%
df.describe()
# Out:
#          disc_year      pl_rade     pl_bmasse       pl_eqt      sy_snum
# count  6127.000000  3728.000000   2358.000000  2713.000000  6128.000000
# mean   2016.954464     5.274184    825.025167   846.276786     1.103296
# std       4.945150    70.275857   1659.862590   489.588319     0.342233
# min    1992.000000    -0.009000     -0.017040   -35.000000     1.000000
# 25%    2014.000000     1.439599      8.902500   516.000000     1.000000
# 50%    2016.000000     2.300000    162.092488   779.150000     1.000000
# 75%    2021.000000     3.710000    794.553263  1134.310000     1.000000
# max    2026.000000  4282.980000  22934.497849  3053.000000     4.000000

# %%
df.to_csv('../data/exoplanets_clean.csv', index=False)
print("File saved!")
# Out:
# File saved!
